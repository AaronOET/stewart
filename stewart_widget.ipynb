# %% [markdown]
# # Stewart Platform Analyzer
#
# Interactive Stewart Platform visualization using ipywidgets.

# %%
# Required for Colab to support interactive matplotlib widgets
from google.colab import output
output.enable_custom_widget_manager()

# %%
# %matplotlib widget
from stewart_widget import StewartPlatformWidget

# %%
app = StewartPlatformWidget()
app.show()
